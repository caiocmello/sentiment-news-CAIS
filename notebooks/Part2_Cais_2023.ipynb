# %%
import pandas as pd

# %%
df = pd.read_csv("../data/dailymail_london.csv")

# %%
df
# Out:
#       Rank        Date                                               Link  \
# 0    122.0  06/06/2008  https://www.dailymail.co.uk/news/article-10245...
# 1     57.0  18/07/2008  https://www.dailymail.co.uk/news/article-10363...
# 2    108.0  24/08/2008  https://www.dailymail.co.uk/news/article-10486...
# 3     86.0  26/08/2008  https://www.dailymail.co.uk/news/article-10492...
# 4    143.0  05/09/2008  https://www.dailymail.co.uk/sport/football/art...
# ..     ...         ...                                                ...
# 993    NaN         NaN                                                NaN
# 994    NaN         NaN                                                NaN
# 995    NaN         NaN                                                NaN
# 996    NaN         NaN                                                NaN
# 997    NaN         NaN                                                NaN
#
#                                                  Title    Labels  Unnamed: 5  \
# ...
